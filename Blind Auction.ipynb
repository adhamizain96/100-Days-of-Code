# %%
bids = {}
bidding_finished = False

def highest_bidder(bidding_record):
    highest_bid = 0
    winning_bidder = ''
    for bidder in bidding_record:
        bid_amount = bidding_record[bidder]
        if bid_amount > highest_bid:
            highest_bid = bid_amount
            winning_bidder = bidder
    print(f"The winner is {winning_bidder} with a bid of ${highest_bid}")

while not bidding_finished:
    bidders = input("What is your Name?: ")
    price = float(input("What is your bid amount?: $"))
    bids[bidders] = price
    should_continue_bidding = input("Are there any other bidders? Type 'Yes' or 'No'.")
    if should_continue_bidding == 'No':
        bidding_finished = True
        highest_bidder(bids)
    elif should_continue_bidding == 'Yes':
        print('Continue Bidding!')
# Out:
# What is your Name?: Zain Adhami
# What is your bid amount?: $87.54
# Are there any other bidders? Type 'Yes' or 'No'.Yes
# Continue Bidding!
# What is your Name?: Moeiz Adhami
# What is your bid amount?: $99.34
# Are there any other bidders? Type 'Yes' or 'No'.No
# The winner is Moeiz Adhami with a bid of $99.34
